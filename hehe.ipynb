# %%
import pandas as pd

# %%
df=pd.read_csv('bookbuy\spiders\Storage_MongoDB\csvdatabookbuy.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\This PC\AppData\Local\Temp\ipykernel_14864\2720604518.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv('bookbuy\spiders\Storage_MongoDB\csvdatabookbuy.csv')

# %%
df
# Out:
#                 Author                                          Book_name  \
# 0     George Macdonald                                   Sau Lưng Gió Bấc
# 1       Lyle & Michael  Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 2          Ngọc Bảo An                                  Mát Mát Lạnh Lạnh
# 3          Harry Dolan                                   Vòng Xoáy Tội Ác
# 4         Amanda Huynh                                                Lam
# ...                ...                                                ...
# 1267      Kudoh Noriko                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268         Trường An                                   Hồ Dương - Tâp 1
# 1269      Karen Dillon                HBR Guide To - Sống Sót Nơi Công Sở
# 1270    Porter Erisman                       Thế Giới Alibaba Của Jack Ma
# 1271       Lê Anh Vinh              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# ...

# %%
df['Status'].value_counts()
# Out:
# Status
# Hết hàng    1224
# Còn hàng      48
# Name: count, dtype: int64
