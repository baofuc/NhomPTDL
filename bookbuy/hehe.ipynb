# %%
import pandas as pd

import numpy as np

# %%
df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sacj\AppData\Local\Temp\ipykernel_20328\2721975166.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')

# %%
df
# Out:
#               Author                                          Book_name  \
# 0     Lyle & Michael  Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1        Ngọc Bảo An                                  Mát Mát Lạnh Lạnh
# 2               Kiệm                             Câu Chuyện Bên Nồi Lẩu
# 3        Harry Dolan                                   Vòng Xoáy Tội Ác
# 4       Amanda Huynh                                                Lam
# ...              ...                                                ...
# 1267    Kudoh Noriko                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268       Trường An                                   Hồ Dương - Tâp 1
# 1269    Karen Dillon                HBR Guide To - Sống Sót Nơi Công Sở
# 1270  Porter Erisman                       Thế Giới Alibaba Của Jack Ma
# 1271     Lê Anh Vinh              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# ...

# %%
df.isna().any()
# Out:
# Author           True
# Book_name       False
# Content          True
# Issuiers        False
# Market_Price    False
# Num_Page        False
# Price           False
# Publish_date    False
# Publisher       False
# Status          False
# Weight          False
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#               Author                                          Book_name  \
# 0     Lyle & Michael  Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1        Ngọc Bảo An                                  Mát Mát Lạnh Lạnh
# 2               Kiệm                             Câu Chuyện Bên Nồi Lẩu
# 3        Harry Dolan                                   Vòng Xoáy Tội Ác
# 4       Amanda Huynh                                                Lam
# ...              ...                                                ...
# 1267    Kudoh Noriko                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268       Trường An                                   Hồ Dương - Tâp 1
# 1269    Karen Dillon                HBR Guide To - Sống Sót Nơi Công Sở
# 1270  Porter Erisman                       Thế Giới Alibaba Của Jack Ma
# 1271     Lê Anh Vinh              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# ...

# %%
df['Status'] = df['Status'].apply(lambda x: 0 if x == 'Hết hàng' else 1)

# %%
df
# Out:
#               Author                                          Book_name  \
# 0     Lyle & Michael  Giáng Sinh Ở Thành Phố Ma Thuật - Tập 3: Âm Mư...
# 1        Ngọc Bảo An                                  Mát Mát Lạnh Lạnh
# 2               Kiệm                             Câu Chuyện Bên Nồi Lẩu
# 3        Harry Dolan                                   Vòng Xoáy Tội Ác
# 4       Amanda Huynh                                                Lam
# ...              ...                                                ...
# 1267    Kudoh Noriko                  Chiếp Chiếp Đi Công Viên Giải Trí
# 1268       Trường An                                   Hồ Dương - Tâp 1
# 1269    Karen Dillon                HBR Guide To - Sống Sót Nơi Công Sở
# 1270  Porter Erisman                       Thế Giới Alibaba Của Jack Ma
# 1271     Lê Anh Vinh              Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# ...

# %%
df['Status'] .value_counts()
# Out:
# Status
# 0    1102
# 1      40
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Market_Price         Price       Status
# count  1.142000e+03  1.142000e+03  1142.000000
# mean   9.131918e+04  7.735727e+04     0.035026
# std    8.558038e+04  7.277095e+04     0.183927
# min    1.000000e+04  7.500000e+03     0.000000
# 25%    5.200000e+04  4.400000e+04     0.000000
# 50%    7.900000e+04  6.700000e+04     0.000000
# 75%    1.090000e+05  9.250000e+04     0.000000
# max    2.000000e+06  1.700000e+06     1.000000

# %%
df[0:30]
# Out:
#                       Author  \
# 0             Lyle & Michael
# 1                Ngọc Bảo An
# 2                       Kiệm
# 3                Harry Dolan
# 4               Amanda Huynh
# 5           George Macdonald
# 6              Oprah Winfrey
# 7            Fiona MacDonald
# 8               Trần Bích Hà
# 9              Hikari Noriko
# 10                    Nguyệt
# 11  Hòa Bình & Cỏ (Chấp bút)
# 12                   Lại Nhĩ
# 13              Chu Đình Tới
# 14            Chris Bradford
# 15               Alon Gratch
# 16                 Đằng Bình
# 17               Bùi Anh Tấn
# 18             Colleen Houck
# 19           Thích Nhất Hạnh
# 20   BS. Trần Thị Huyên Thảo
# 21             Minh Hiểu Khê
# 22                 Jenny Han
# 23               Vũ Minh Đức
# 24          Nguyễn Hồng Năng
# 25                 Minh Hiền
# 26            Vũ Trọng Phụng
# 27             Takeshi Obata
# 28              Nguyên Hương
# 29              Lại Văn Long
#
# ...

# %%
missing_data = df.isnull()
missing_data.head(5)
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Author
# Author
# False    1142
# Name: count, dtype: int64
#
# Book_name
# Book_name
# False    1142
# Name: count, dtype: int64
#
# Content
# Content
# False    1142
# Name: count, dtype: int64
#
# Issuiers
# Issuiers
# False    1142
# Name: count, dtype: int64
#
# Market_Price
# Market_Price
# False    1142
# Name: count, dtype: int64
#
# Num_Page
# Num_Page
# False    1142
# Name: count, dtype: int64
#
# Price
# Price
# False    1142
# Name: count, dtype: int64
#
# Publish_date
# Publish_date
# False    1142
# Name: count, dtype: int64
#
# Publisher
# Publisher
# False    1142
# Name: count, dtype: int64
#
# Status
# Status
# False    1142
# Name: count, dtype: int64
#
# Weight
# Weight
# False    1142
# Name: count, dtype: int64

# %%
df['Content'] = df['Content'].apply(lambda x: '"Đang cập nhật"' if len(x) < 20 else x)

# %%
df.dtypes

# %%
# Thay thế "Đang" bằng NaN trong cột Publish_date
df['Publish_date'].replace("Đang", np.nan, inplace=True)

# Loại bỏ các hàng có giá trị null
df.dropna(subset=['Publish_date'], inplace=True)

# Hiển thị 5 hàng đầu tiên sau khi thực hiện
df.head(5)

# %%
df.reset_index(drop=True, inplace=True)
