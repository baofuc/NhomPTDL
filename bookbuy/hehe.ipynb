# %%
import pandas as pd

# %%
df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\This PC\AppData\Local\Temp\ipykernel_6184\2721975166.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')
# C:\Users\This PC\AppData\Local\Temp\ipykernel_6184\2721975166.py:1: SyntaxWarning: invalid escape sequence '\s'
#   df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df=pd.read_csv('bookbuy\spiders\csvdatabookbuy.csv')
#
# File c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bookbuy\\spiders\\csvdatabookbuy.csv'

# %%
df
# Out:
#                 Author                              Book_name  \
# 0          Ngọc Bảo An                      Mát Mát Lạnh Lạnh
# 1     George Macdonald                       Sau Lưng Gió Bấc
# 2                 Kiệm                 Câu Chuyện Bên Nồi Lẩu
# 3          Harry Dolan                       Vòng Xoáy Tội Ác
# 4         Amanda Huynh                                    Lam
# ...                ...                                    ...
# 1267      Kudoh Noriko      Chiếp Chiếp Đi Công Viên Giải Trí
# 1268         Trường An                       Hồ Dương - Tâp 1
# 1269      Karen Dillon    HBR Guide To - Sống Sót Nơi Công Sở
# 1270    Porter Erisman           Thế Giới Alibaba Của Jack Ma
# 1271       Lê Anh Vinh  Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# 0     Ngắn và rất ngắn. Mát mát và lạnh lạnh. 24 mản...     Nhã Nam
# 1     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...     Nhã Nam
# 2     Kiệm là một cây viết trưởng thành từ Mann Up. ...   Bách Việt
# 3     là cuốn tiểu thuyết đầu tiên của Dolan trong s...   Bách Việt
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...     NXB Trẻ
# ...                                                 ...         ...
# 1267                                       chiếp chiếp.     Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...  NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;  Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...     NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...     Thái Hà
#
#       Market_Price Num_Page   Price Publish_date            Publisher  \
# 0            55000      130   46500   13/07/2016    NXB Hội Nhà Văn
# 1            90000      420   76500   13/07/2016    NXB Hội Nhà Văn
# 2            63000      200   53500   20/07/2016          NXB Dân Trí
# 3           125000      440  106000   05/07/2016  NXB Lao Động Xã Hội
# 4            85000      164   72000   14/07/2016              NXB Trẻ
# ...            ...      ...     ...          ...                  ...
# 1267         44000       32   37000   22/09/2017         NXB Thế Giới
# 1268        217000      728  184000   01/09/2017           NXB Phụ Nữ
# 1269         99000      228   84000   22/09/2017         NXB Thế Giới
# 1270        105000      322   89000   01/09/2017              NXB Trẻ
# 1271         49000       34   41500   10/10/2017         NXB Thế Giới
#
#         Status Weight
# 0     Hết hàng    400
# 1     Hết hàng    650
# 2     Hết hàng    450
# 3     Hết hàng    700
# 4     Hết hàng    300
# ...        ...    ...
# 1267  Hết hàng    200
# 1268  Hết hàng    950
# 1269  Hết hàng    370
# 1270  Hết hàng    522
# 1271  Hết hàng    184
#
# [1272 rows x 11 columns]

# %%
df.isna().any()
# Out:
# Author           True
# Book_name       False
# Content          True
# Issuiers        False
# Market_Price    False
# Num_Page        False
# Price           False
# Publish_date    False
# Publisher       False
# Status          False
# Weight          False
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                 Author                              Book_name  \
# 0          Ngọc Bảo An                      Mát Mát Lạnh Lạnh
# 1     George Macdonald                       Sau Lưng Gió Bấc
# 2                 Kiệm                 Câu Chuyện Bên Nồi Lẩu
# 3          Harry Dolan                       Vòng Xoáy Tội Ác
# 4         Amanda Huynh                                    Lam
# ...                ...                                    ...
# 1267      Kudoh Noriko      Chiếp Chiếp Đi Công Viên Giải Trí
# 1268         Trường An                       Hồ Dương - Tâp 1
# 1269      Karen Dillon    HBR Guide To - Sống Sót Nơi Công Sở
# 1270    Porter Erisman           Thế Giới Alibaba Của Jack Ma
# 1271       Lê Anh Vinh  Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# 0     Ngắn và rất ngắn. Mát mát và lạnh lạnh. 24 mản...     Nhã Nam
# 1     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...     Nhã Nam
# 2     Kiệm là một cây viết trưởng thành từ Mann Up. ...   Bách Việt
# 3     là cuốn tiểu thuyết đầu tiên của Dolan trong s...   Bách Việt
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...     NXB Trẻ
# ...                                                 ...         ...
# 1267                                       chiếp chiếp.     Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...  NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;  Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...     NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...     Thái Hà
#
#       Market_Price Num_Page   Price Publish_date            Publisher  \
# 0            55000      130   46500   13/07/2016    NXB Hội Nhà Văn
# 1            90000      420   76500   13/07/2016    NXB Hội Nhà Văn
# 2            63000      200   53500   20/07/2016          NXB Dân Trí
# 3           125000      440  106000   05/07/2016  NXB Lao Động Xã Hội
# 4            85000      164   72000   14/07/2016              NXB Trẻ
# ...            ...      ...     ...          ...                  ...
# 1267         44000       32   37000   22/09/2017         NXB Thế Giới
# 1268        217000      728  184000   01/09/2017           NXB Phụ Nữ
# 1269         99000      228   84000   22/09/2017         NXB Thế Giới
# 1270        105000      322   89000   01/09/2017              NXB Trẻ
# 1271         49000       34   41500   10/10/2017         NXB Thế Giới
#
#         Status Weight
# 0     Hết hàng    400
# 1     Hết hàng    650
# 2     Hết hàng    450
# 3     Hết hàng    700
# 4     Hết hàng    300
# ...        ...    ...
# 1267  Hết hàng    200
# 1268  Hết hàng    950
# 1269  Hết hàng    370
# 1270  Hết hàng    522
# 1271  Hết hàng    184
#
# [1142 rows x 11 columns]

# %%
df['Status'] = df['Status'].apply(lambda x: 0 if x == 'Hết hàng' else 1)

# %%
df
# Out:
#                 Author                              Book_name  \
# 0          Ngọc Bảo An                      Mát Mát Lạnh Lạnh
# 1     George Macdonald                       Sau Lưng Gió Bấc
# 2                 Kiệm                 Câu Chuyện Bên Nồi Lẩu
# 3          Harry Dolan                       Vòng Xoáy Tội Ác
# 4         Amanda Huynh                                    Lam
# ...                ...                                    ...
# 1267      Kudoh Noriko      Chiếp Chiếp Đi Công Viên Giải Trí
# 1268         Trường An                       Hồ Dương - Tâp 1
# 1269      Karen Dillon    HBR Guide To - Sống Sót Nơi Công Sở
# 1270    Porter Erisman           Thế Giới Alibaba Của Jack Ma
# 1271       Lê Anh Vinh  Học Toán Qua Truyện Cổ Tích - Cây Khế
#
#                                                 Content    Issuiers  \
# 0     Ngắn và rất ngắn. Mát mát và lạnh lạnh. 24 mản...     Nhã Nam
# 1     Nếu bạn năm tuổi, bạn sẽ thấy đây là một cuốn ...     Nhã Nam
# 2     Kiệm là một cây viết trưởng thành từ Mann Up. ...   Bách Việt
# 3     là cuốn tiểu thuyết đầu tiên của Dolan trong s...   Bách Việt
# 4     Nhân vật chính của các mẩu truyện hay tản văn ...     NXB Trẻ
# ...                                                 ...         ...
# 1267                                       chiếp chiếp.     Nhã Nam
# 1268  Trong những năm tháng đó, ai đúng ai sai khôn...  NXB Phụ Nữ
# 1269  • Chống lại những kẻ đâm sau lưng và ưa bắt nạt ;  Alphabooks
# 1270  Tác giả viết sách còn làm một bộ phim tài liệu...     NXB Trẻ
# 1271  là sản phẩm nằm trong bộ sản phẩm Học toán qua...     Thái Hà
#
#       Market_Price Num_Page   Price Publish_date            Publisher  Status  \
# 0            55000      130   46500   13/07/2016    NXB Hội Nhà Văn       0
# 1            90000      420   76500   13/07/2016    NXB Hội Nhà Văn       0
# 2            63000      200   53500   20/07/2016          NXB Dân Trí       0
# 3           125000      440  106000   05/07/2016  NXB Lao Động Xã Hội       0
# 4            85000      164   72000   14/07/2016              NXB Trẻ       0
# ...            ...      ...     ...          ...                  ...     ...
# 1267         44000       32   37000   22/09/2017         NXB Thế Giới       0
# 1268        217000      728  184000   01/09/2017           NXB Phụ Nữ       0
# 1269         99000      228   84000   22/09/2017         NXB Thế Giới       0
# 1270        105000      322   89000   01/09/2017              NXB Trẻ       0
# 1271         49000       34   41500   10/10/2017         NXB Thế Giới       0
#
#      Weight
# 0       400
# 1       650
# 2       450
# 3       700
# 4       300
# ...     ...
# 1267    200
# 1268    950
# 1269    370
# 1270    522
# 1271    184
#
# [1142 rows x 11 columns]

# %%
df['Status'] .value_counts()
# Out:
# Status
# 0    1102
# 1      40
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Market_Price         Price       Status
# count  1.142000e+03  1.142000e+03  1142.000000
# mean   9.131918e+04  7.735727e+04     0.035026
# std    8.558038e+04  7.277095e+04     0.183927
# min    1.000000e+04  7.500000e+03     0.000000
# 25%    5.200000e+04  4.400000e+04     0.000000
# 50%    7.900000e+04  6.700000e+04     0.000000
# 75%    1.090000e+05  9.250000e+04     0.000000
# max    2.000000e+06  1.700000e+06     1.000000

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6184\2465499897.py in ?()
# ----> 1 df.type()
#
# c:\Users\This PC\OneDrive\Desktop\btl\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'
